# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
# 1. Load your data
train_df = pd.read_csv('../data/challenge_1/train/classification_data.csv')
val_df = pd.read_csv('../data/challenge_1/val/classification_data.csv')

# %%
X_train = train_df["description"]
y_train = train_df["responsible_entity_id"]
X_val = val_df["description"]

# %%
# 4. Create a pipeline: TF-IDF vectorizer + Decision Tree
pipeline = Pipeline([
    ("tfidf", TfidfVectorizer()),  # converts text into numeric features
    ("clf", DecisionTreeClassifier())  # classifier
])

# %%
# 5. Train the model
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', DecisionTreeClassifier())])

# %%
# 6. Make predictions
y_pred = pipeline.predict(X_test)

# %%
# 7. Evaluate
print(classification_report(y_test, y_pred))
# Out:
#                                                   precision    recall  f1-score   support
#
# BUND_BUNDESMINISTERIUM_FÜR_DIGITALES_UND_VERKEHR       1.00      1.00      1.00        16
#                                       LAND_01_BM       1.00      1.00      1.00         2
#                                       LAND_01_SM       1.00      1.00      1.00         3
#                                       LAND_01_UM       1.00      1.00      1.00         2
#                                       LAND_02_BM       1.00      1.00      1.00         1
#                                       LAND_02_FM       1.00      1.00      1.00         1
#                                       LAND_02_MW       1.00      1.00      1.00         1
#                                       LAND_02_SM       1.00      1.00      1.00         6
#                                       LAND_02_UM       1.00      1.00      1.00         2
#                                       LAND_02_VM       1.00      1.00      1.00         1
#                                       LAND_03_BM       1.00      1.00      1.00         3
#                                       LAND_03_FM       1.00      1.00      1.00         1
#                                       LAND_03_IM       1.00      1.00      1.00         2
#                                       LAND_03_SM       1.00      1.00      1.00         2
#                                       LAND_03_UM       1.00      1.00      1.00         2
#                                       LAND_04_BM       1.00      1.00      1.00         1
#                                       LAND_04_IM       1.00      1.00      1.00         1
#                                       LAND_04_MW       1.00      1.00      1.00         1
#                                       LAND_04_SM       1.00      1.00      1.00         2
#                                       LAND_04_UM       1.00      1.00      1.00         1
#                                       LAND_05_MW       1.00      1.00      1.00         2
#                                       LAND_05_SM       1.00      1.00      1.00         2
#                                       LAND_05_VM       1.00      1.00      1.00         1
#                                       LAND_06_BM       1.00      1.00      1.00         1
#                                       LAND_06_IM       1.00      1.00      1.00         2
#                                       LAND_06_SM       1.00      1.00      1.00         2
#                                       LAND_06_VM       1.00      1.00      1.00         1
#                                       LAND_07_BM       1.00      1.00      1.00         2
#                                       LAND_07_IM       1.00      1.00      1.00         1
#                                       LAND_07_SM       1.00      1.00      1.00         2
#                                       LAND_07_UM       1.00      1.00      1.00         2
#                                       LAND_07_VM       1.00      1.00      1.00         1
#                                       LAND_08_BM       1.00      1.00      1.00         1
#                                       LAND_08_GM       1.00      1.00      1.00         2
#                                       LAND_08_SM       1.00      1.00      1.00         1
#                                       LAND_08_VM       1.00      1.00      1.00         2
#                                       LAND_09_BM       1.00      1.00      1.00         2
#                                       LAND_09_GM       1.00      1.00      1.00         2
#                                       LAND_09_IM       1.00      1.00      1.00         1
#                                       LAND_09_MW       1.00      1.00      1.00         1
#                                       LAND_09_SM       1.00      1.00      1.00         2
#                                       LAND_09_UM       1.00      1.00      1.00         2
#                                       LAND_09_VM       1.00      1.00      1.00         3
#                                       LAND_10_BM       1.00      1.00      1.00         2
#                                       LAND_10_IM       1.00      1.00      1.00         1
#                                       LAND_10_MW       1.00      1.00      1.00         1
#                                       LAND_10_SM       1.00      1.00      1.00         3
#                                       LAND_10_UM       1.00      1.00      1.00         2
#                                       LAND_11_BM       1.00      1.00      1.00         1
#                                       LAND_11_SM       1.00      1.00      1.00         1
#                                       LAND_11_UM       1.00      1.00      1.00         2
#                                       LAND_11_VM       1.00      1.00      1.00         2
#                                       LAND_12_BM       1.00      1.00      1.00         2
#                                       LAND_12_IM       1.00      1.00      1.00         2
#                                       LAND_12_MW       1.00      1.00      1.00         2
#                                       LAND_12_SM       1.00      1.00      1.00         1
#                                       LAND_13_BM       1.00      1.00      1.00         1
#                                       LAND_13_GM       1.00      1.00      1.00         1
#                                       LAND_13_IM       1.00      1.00      1.00         1
#                                       LAND_13_MW       1.00      1.00      1.00         2
#                                       LAND_13_SM       1.00      1.00      1.00         3
#                                       LAND_14_BM       1.00      1.00      1.00         2
#                                       LAND_14_GM       1.00      1.00      1.00         1
#                                       LAND_14_IM       1.00      1.00      1.00         2
#                                       LAND_14_SM       1.00      1.00      1.00         2
#                                       LAND_14_VM       1.00      1.00      1.00         1
#                                       LAND_15_FM       1.00      1.00      1.00         1
#                                       LAND_15_IM       1.00      1.00      1.00         1
#                                       LAND_15_MW       1.00      1.00      1.00         1
#                                       LAND_15_SM       1.00      1.00      1.00         2
#                                       LAND_15_UM       1.00      1.00      1.00         1
#                                       LAND_15_VM       1.00      1.00      1.00         2
#                                       LAND_16_BM       1.00      1.00      1.00         1
#                                       LAND_16_SM       1.00      1.00      1.00         1
#                                       LAND_16_UM       1.00      1.00      1.00         1
#                                       LAND_16_VM       1.00      1.00      1.00         1
#
#                                         accuracy                           1.00       139
#                                        macro avg       1.00      1.00      1.00       139
#                                     weighted avg       1.00      1.00      1.00       139
