# %%
import pandas as pd
import json

# %%
# Load training and validation data
train_df = pd.read_csv('../data/challenge_1/train/classification_data.csv')
val_df = pd.read_csv('../data/challenge_1/val/classification_data.csv')
test_df = pd.read_csv('../data/challenge_1/test/classification_data.csv')

# Load metadata
with open('../data/shared/entity_catalog.json', encoding='utf-8') as f:
    entity_catalog = json.load(f)

with open('../data/shared/categories.json', encoding='utf-8') as f:
    categories_info = json.load(f)

# %%
train_df.head()
# Out:
#                   issue_id            timestamp         category  \
# 0  ISS_20250613034209_7483  2023-11-12 03:54:00       Gesundheit
# 1  ISS_20250613034253_2513  2024-12-26 06:24:00  Digitalisierung
# 2  ISS_20250613033812_4910  2023-06-04 12:10:00          Verkehr
# 3  ISS_20250613033659_2513  2024-09-13 11:25:00          Verkehr
# 4  ISS_20250613034155_1027  2024-02-20 14:58:00           Umwelt
#
#                                          description municipality district  \
# 0  Die Wartezeit in der Notaufnahme des Klinikums...     Chemnitz    Stadt
# 1  Das Online-Portal der Stadt funktioniert seit ...     Moringen    Stadt
# 2  Die Baustelle an der B176 bei Frohburg dauert ...     Frohburg    Stadt
# 3  Die Baustelle in der Leipziger Straße dauert s...       Artern    Stadt
# 4  Die Grünschnittsammelstelle an der Münchener S...      Olching    Stadt
#
#            state age_group  gender   origin  ... hour day_of_week  \
# 0        Sachsen     55-64  female  citizen  ...    3           6
# 1  Niedersachsen     35-44  female  citizen  ...    6           3
# 2        Sachsen     25-34    male  citizen  ...   12           6
# 3      Thüringen     35-44    male  citizen  ...   11           4
# 4         Bayern     45-54    male  citizen  ...   14           1
#
#   day_of_month  week_of_year  month  quarter  is_weekend  is_business_hours  \
# 0           12            45     11        4        True              False
# 1           26            52     12        4       False              False
# 2            4            22      6        2        True               True
# 3           13            37      9        3       False               True
# 4           20             8      2        1       False               True
#
#    is_morning  is_afternoon
# 0       False         False
# 1        True         False
# 2        True          True
# 3        True         False
# 4       False          True
#
# [5 rows x 29 columns]
